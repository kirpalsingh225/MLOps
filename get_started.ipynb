# %% [markdown]
# ## MLFLOW TRACKING SERVER

# %%
import mlflow

# %%
mlflow.set_tracking_uri("http://127.0.0.1:5000")

# %%
mlflow.set_experiment("check local host connection")


with mlflow.start_run():
    mlflow.log_metric("test", 1)
# Out:
# 🏃 View run bright-yak-978 at: http://127.0.0.1:5000/#/experiments/149974386420918946/runs/a9b6905c76314baf8a54b6cf35605cd4
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/149974386420918946
